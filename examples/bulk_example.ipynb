# %% [markdown]
# <div class="alert alert-block alert-success">
#  Bulk Feature Computation - Example
# </div>

# %%
import dill as pickle
from cosinorage.datahandlers import GenericDataHandler, plot_enmo
from cosinorage.features import WearableFeatures, dashboard, BulkWearableFeatures
from cosinorage.bioages import CosinorAge

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
preprocess_args = {
    'autocalib_sd_criter': 0.01,
    'autocalib_sphere_crit': 0.02,
    'filter_type': 'lowpass',
    'filter_cutoff': 2,
    'wear_sd_crit': 0.00013,
    'wear_range_crit': 0.00067,
    'wear_window_length': 45,
    'wear_window_skip': 7,
    'required_daily_coverage': 0.5
}

# %%
generic_handler1 = GenericDataHandler(file_path='../data/public data/processed/watch_acc/1155FF54-63D3-4AB2-9863-8385D0BD0A13_watch_acc.csv', 
                                            data_format='csv',
                                            data_type='accelerometer',
                                            time_format='unix',
                                            time_column='timestamp',
                                            data_columns=['x', 'y', 'z'],
                                            preprocess_args=preprocess_args,
                                            verbose=True
                                            )

generic_handler2 = GenericDataHandler(file_path='../data/public data/processed/watch_acc/1DBB0F6F-1F81-4A50-9DF4-CD62ACFA4842_watch_acc.csv', 
                                            data_format='csv',
                                            data_type='accelerometer',
                                            time_format='unix',
                                            time_column='timestamp',
                                            data_columns=['x', 'y', 'z'],
                                            preprocess_args=preprocess_args,
                                            verbose=True
                                            )

generic_handler3 = GenericDataHandler(file_path='../data/public data/processed/watch_acc/78A91A4E-4A51-4065-BDA7-94755F0BB3BB_watch_acc.csv', 
                                            data_format='csv',
                                            data_type='accelerometer',
                                            time_format='unix',
                                            time_column='timestamp',
                                            data_columns=['x', 'y', 'z'],
                                            preprocess_args=preprocess_args,
                                            verbose=True
                                            )
# Out:
# Read csv file from ../data/public data/processed/watch_acc/1155FF54-63D3-4AB2-9863-8385D0BD0A13_watch_acc.csv
# Loaded 17681496 Count data records from ../data/public data/processed/watch_acc/1155FF54-63D3-4AB2-9863-8385D0BD0A13_watch_acc.csv
# Filtered out 2561496/15120000 accelerometer records due to filtering out first and last day
# Filtered out 0/15120000 records due to incomplete daily coverage
# Filtered out 0/15120000 records due to filtering for longest consecutive sequence of days
# Resampled 15120000 to 10080 timestamps
# Calibration done
# Noise removal done
# Wear detection done
# Wear time calculated
# Calculated ENMO for 10080 accelerometer records
# Preprocessed accelerometer data
# Aggregated ENMO values at the minute level leading to 10080 records
# __load_data executed in 25.16 seconds
# /Users/jacquesleooscar/Documents/Education/ETHZ/Curriculum/Semester04/04MasterThesis/CosinorAge/venv/lib/python3.9/site-packages/skdh/preprocessing/calibrate.py:163: UserWarning: Less than 72 hours of data (0.1119998936 hours). No Calibration performed
#   warn(
# Read csv file from ../data/public data/processed/watch_acc/1DBB0F6F-1F81-4A50-9DF4-CD62ACFA4842_watch_acc.csv
# Loaded 16642023 Count data records from ../data/public data/processed/watch_acc/1DBB0F6F-1F81-4A50-9DF4-CD62ACFA4842_watch_acc.csv
# Filtered out 1522023/15120000 accelerometer records due to filtering out first and last day
# Filtered out 0/15120000 records due to incomplete daily coverage
# Filtered out 0/15120000 records due to filtering for longest consecutive sequence of days
# Resampled 15120000 to 10080 timestamps
# Calibration done
# Noise removal done
# Wear detection done
# Wear time calculated
# Calculated ENMO for 10080 accelerometer records
# Preprocessed accelerometer data
# Aggregated ENMO values at the minute level leading to 10080 records
# __load_data executed in 24.16 seconds
# /Users/jacquesleooscar/Documents/Education/ETHZ/Curriculum/Semester04/04MasterThesis/CosinorAge/venv/lib/python3.9/site-packages/skdh/preprocessing/calibrate.py:163: UserWarning: Less than 72 hours of data (0.1119998936 hours). No Calibration performed
#   warn(
# Read csv file from ../data/public data/processed/watch_acc/78A91A4E-4A51-4065-BDA7-94755F0BB3BB_watch_acc.csv
# Loaded 20009272 Count data records from ../data/public data/processed/watch_acc/78A91A4E-4A51-4065-BDA7-94755F0BB3BB_watch_acc.csv
# Filtered out 569272/19440000 accelerometer records due to filtering out first and last day
# Filtered out 0/19440000 records due to incomplete daily coverage
# Filtered out 0/19440000 records due to filtering for longest consecutive sequence of days
# Resampled 19440000 to 12960 timestamps
# Calibration done
# Noise removal done
# Wear detection done
# Wear time calculated
# Calculated ENMO for 12960 accelerometer records
# Preprocessed accelerometer data
# Aggregated ENMO values at the minute level leading to 12960 records
# __load_data executed in 30.13 seconds
# /Users/jacquesleooscar/Documents/Education/ETHZ/Curriculum/Semester04/04MasterThesis/CosinorAge/venv/lib/python3.9/site-packages/skdh/preprocessing/calibrate.py:163: UserWarning: Less than 72 hours of data (0.1439998632 hours). No Calibration performed
#   warn(

# %%
features_args = {
    'sleep_ck_sf': 0.01,
    'sleep_rescore': True,
    'pa_cutpoint_sl': 15,
    'pa_cutpoint_lm': 35,
    'pa_cutpoint_mv': 70,
}

# %%
handlers = [generic_handler1, generic_handler2, generic_handler3]
bulk_features = BulkWearableFeatures(handlers)

# %%
bulk_features.get_individual_features()
# Out:
# [{'cosinor': {'mesor': np.float64(18.33668513079475),
#    'amplitude': np.float64(15.45586508064733),
#    'acrophase': np.float64(-0.390428474733997),
#    'acrophase_time': 89.47961521595239},
#   'nonparam': {'IS': 0.13085791939673472,
#    'IV': 0.9789429183731128,
#    'M10': [18.845061614713657,
#     14.15409703220245,
#     19.243429036076183,
#     23.157607660229225,
#     111.37907726796381,
#     13.385476560792368,
#     17.91060205513853],
#    'M10_start': [Timestamp('2016-05-27 02:35:00'),
#     Timestamp('2016-05-28 00:00:00'),
#     Timestamp('2016-05-29 10:44:00'),
#     Timestamp('2016-05-30 00:35:00'),
#     Timestamp('2016-05-31 00:00:00'),
#     Timestamp('2016-06-01 10:18:00'),
#     Timestamp('2016-06-02 12:47:00')],
#    'L5': [3.8437458447006527,
#     1.0191609551072487,
#     2.123605505384835,
#     1.398969540310142,
#     0.0,
#     1.6329114333910058,
#     2.3166728954646687],
#    'L5_start': [Timestamp('2016-05-27 12:38:00'),
#     Timestamp('2016-05-28 14:36:00'),
#     Timestamp('2016-05-29 00:16:00'),
#     Timestamp('2016-05-30 11:32:00'),
#     Timestamp('2016-05-31 04:57:00'),
#     Timestamp('2016-06-01 06:37:00'),
#     Timestamp('2016-06-02 07:13:00')],
#    'RA': [0.6611769171582652,
#     0.865663530408613,
#     0.8012259959364836,
#     0.8860615199841928,
#     1.0,
#     0.7825450462428546,
#     0.7709357388850263]},
#   'physical_activity': {'sedentary': [998, 1202, 1002, 918, 1101, 1150, 984],
#    'light': [1, 0, 0, 1, 0, 0, 1],
#    'moderate': [4, 0, 1, 0, 0, 0, 1],
#    'vigorous': [437, 238, 437, 521, 339, 290, 454]},
#   'sleep': {'TST': [777, 1063, 783, 804, 1026, 1001, 851],
#    'WASO': [566, 377, 635, 625, 395, 433, 564],
#    'PTA': [53.958, 73.819, 54.375, 55.833, 71.25, 69.514, 59.097],
#    'NWB': [30, 29, 32, 23, 14, 27, 25],
#    'SOL': [97, 0, 0, 11, 0, 3, 25],
#    'SRI': -12.359773652337921,
#    'SRI_flag': 'negative SRI - very low sleep consistency'}},
#  {'cosinor': {'mesor': np.float64(7.584048348975772),
#    'amplitude': np.float64(2.662223049591489),
#    'acrophase': np.float64(-0.3164066895879829),
#    'acrophase_time': 72.51507169238941},
#   'nonparam': {'IS': 0.1459308942046172,
#    'IV': 1.1607959708255182,
#    'M10': [9.797563879516524,
#     1.4456416790982396,
#     10.795596967073502,
#     30.655162088319642,
#     12.893722627813597,
#     13.855728413647851,
#     11.665052079666154],
#    'M10_start': [Timestamp('2015-08-27 11:39:00'),
#     Timestamp('2015-08-28 14:00:00'),
#     Timestamp('2015-08-29 00:00:00'),
#     Timestamp('2015-08-30 01:46:00'),
#     Timestamp('2015-08-31 00:00:00'),
#     Timestamp('2015-09-01 09:20:00'),
#     Timestamp('2015-09-02 13:18:00')],
#    'L5': [1.036200665918228,
#     0.0,
#     0.01392653328398404,
#     0.0,
#     0.0,
#     0.3470112724888848,
#     0.7602467921068637],
#    'L5_start': [Timestamp('2015-08-27 08:52:00'),
#     Timestamp('2015-08-28 00:00:00'),
#     Timestamp('2015-08-29 10:06:00'),
#     Timestamp('2015-08-30 11:46:00'),
#     Timestamp('2015-08-31 11:17:00'),
#     Timestamp('2015-09-01 04:13:00'),
#     Timestamp('2015-09-02 03:42:00')],
#    'RA': [0.8087090297056763,
#     1.0,
#     0.9974232845169312,
#     1.0,
#     1.0,
#     0.9511346007661322,
#     0.8776292144032136]},
#   'physical_activity': {'sedentary': [1161, 1378, 1207, 1102, 1244, 968, 1179],
#    'light': [0, 1, 0, 0, 0, 0, 0],
#    'moderate': [1, 1, 2, 1, 3, 0, 3],
#    'vigorous': [278, 60, 231, 337, 193, 472, 258]},
#   'sleep': {'TST': [1033, 1392, 1108, 1066, 1185, 944, 1166],
#    'WASO': [372, 43, 316, 374, 255, 496, 274],
#    'PTA': [71.736, 96.667, 76.944, 74.028, 82.292, 65.556, 80.972],
#    'NWB': [17, 2, 21, 12, 17, 16, 22],
#    'SOL': [35, 0, 16, 0, 0, 0, 0],
#    'SRI': 14.464409808398699}},
#  {'cosinor': {'mesor': np.float64(14.537591173732883),
#    'amplitude': np.float64(1.9815330147667622),
#    'acrophase': np.float64(-1.4031904956764611),
#    'acrophase_time': 321.58757302052487},
#   'nonparam': {'IS': 0.08259620615618209,
#    'IV': 1.284048499736273,
#    'M10': [44.74099897456254,
#     16.95838911645537,
#     13.775001091196797,
#     31.7548117381225,
#     36.936606062469146,
#     22.26639267699287,
#     5.372102545872586,
#     9.628638719852567,
#     23.672755309471366],
#    'M10_start': [Timestamp('2015-12-02 00:00:00'),
#     Timestamp('2015-12-03 07:11:00'),
#     Timestamp('2015-12-04 14:00:00'),
#     Timestamp('2015-12-05 04:11:00'),
#     Timestamp('2015-12-06 11:05:00'),
#     Timestamp('2015-12-07 02:12:00'),
#     Timestamp('2015-12-08 12:08:00'),
#     Timestamp('2015-12-09 06:19:00'),
#     Timestamp('2015-12-10 03:14:00')],
#    'L5': [0.0,
#     0.6718308391183799,
#     2.270301415002167,
#     11.823610027558452,
#     5.550700543907478,
#     7.0003773340292055,
#     0.9190959427352485,
#     1.135738270140157,
#     8.629169139951257],
#    'L5_start': [Timestamp('2015-12-02 08:57:00'),
#     Timestamp('2015-12-03 00:00:00'),
#     Timestamp('2015-12-04 01:43:00'),
#     Timestamp('2015-12-05 14:27:00'),
#     Timestamp('2015-12-06 04:24:00'),
#     Timestamp('2015-12-07 12:12:00'),
#     Timestamp('2015-12-08 07:01:00'),
#     Timestamp('2015-12-09 00:00:00'),
#     Timestamp('2015-12-10 18:38:00')],
#    'RA': [1.0,
#     0.923786448403784,
#     0.7170135727730834,
#     0.45736400959477486,
#     0.7387125244096122,
#     0.5216159944269344,
#     0.7078153091498999,
#     0.7889820709185466,
#     0.46571795414464867]},
#   'physical_activity': {'sedentary': [1057,
#     716,
#     1036,
#     191,
#     693,
#     1010,
#     1232,
#     1186,
#     805],
#    'light': [0, 0, 0, 1, 2, 0, 1, 1, 0],
#    'moderate': [1, 0, 2, 0, 0, 2, 0, 0, 2],
#    'vigorous': [382, 724, 402, 1248, 745, 428, 207, 253, 633]},
#   'sleep': {'TST': [992, 621, 923, 137, 552, 814, 1124, 1031, 671],
#    'WASO': [439, 498, 417, 163, 768, 623, 316, 409, 769],
#    'PTA': [68.889,
#     43.125,
#     64.097,
#     9.514,
#     38.333,
#     56.528,
#     78.056,
#     71.597,
#     46.597],
#    'NWB': [14, 20, 30, 6, 22, 29, 24, 28, 21],
#    'SOL': [9, 0, 96, 22, 120, 3, 0, 0, 0],
#    'SRI': -13.350320438576176,
#    'SRI_flag': 'negative SRI - very low sleep consistency'}}]

# %%
bulk_features.get_distribution_stats()
# Out:
# {'cosinor_mesor': {'count': 3,
#   'mean': 13.486108217834468,
#   'std': 4.452266220352675,
#   'min': 7.584048348975772,
#   'max': 18.33668513079475,
#   'median': 14.537591173732883,
#   'q25': 11.060819761354328,
#   'q75': 16.437138152263817,
#   'iqr': 5.376318390909489,
#   'mode': 7.584048348975772,
#   'skewness': -0.8354712199598264,
#   'kurtosis': nan},
#  'cosinor_amplitude': {'count': 3,
#   'mean': 6.69987371500186,
#   'std': 6.197654036129098,
#   'min': 1.9815330147667622,
#   'max': 15.45586508064733,
#   'median': 2.662223049591489,
#   'q25': 2.321878032179126,
#   'q75': 9.059044065119409,
#   'iqr': 6.737166032940283,
#   'mode': 1.9815330147667622,
#   'skewness': 1.7163940476944628,
#   'kurtosis': nan},
#  'cosinor_acrophase': {'count': 3,
#   'mean': -0.703341886666147,
#   'std': 0.4957895136845234,
#   'min': -1.4031904956764611,
#   'max': -0.3164066895879829,
#   'median': -0.390428474733997,
#   'q25': -0.8968094852052291,
#   'q75': -0.35341758216098995,
#   'iqr': 0.5433919030442391,
#   'mode': -1.4031904956764611,
#   'skewness': -1.7031391529856625,
#   'kurtosis': nan},
#  'cosinor_acrophase_time': {'count': 3,
#   'mean': 161.19408664295557,
#   'std': 113.62658664386709,
#   'min': 72.51507169238941,
#   'max': 321.58757302052487,
#   'median': 89.47961521595239,
#   'q25': 80.9973434541709,
#   'q75': 205.53359411823863,
#   'iqr': 124.53625066406772,
#   'mode': 72.51507169238941,
#   'skewness': 1.7031391529856632,
#   'kurtosis': nan},
#  'nonparam_IS': {'count': 3,
#   'mean': 0.11979500658584465,
#   'std': 0.027013721296706036,
#   'min': 0.08259620615618209,
#   'max': 0.1459308942046172,
#   'median': 0.13085791939673472,
#   'q25': 0.10672706277645841,
#   'q75': 0.13839440680067594,
#   'iqr': 0.03166734402421753,
#   'mode': 0.08259620615618209,
#   'skewness': -1.3364664453067026,
#   'kurtosis': nan},
#  'nonparam_IV': {'count': 3,
#   'mean': 1.1412624629783015,
#   'std': 0.12532231083982606,
#   'min': 0.9789429183731128,
#   'max': 1.284048499736273,
#   'median': 1.1607959708255182,
#   'q25': 1.0698694445993155,
#   'q75': 1.2224222352808956,
#   'iqr': 0.15255279068158,
#   'mode': 0.9789429183731128,
#   'skewness': -0.5634134863789615,
#   'kurtosis': nan},
#  'nonparam_M10': {'count': 3,
#   'mean': 22.319546266165272,
#   'std': 7.412312432050411,
#   'min': 13.015495390733646,
#   'max': 31.153621603873745,
#   'median': 22.789521803888416,
#   'q25': 17.90250859731103,
#   'q75': 26.971571703881082,
#   'iqr': 9.069063106570052,
#   'mode': 13.015495390733646,
#   'skewness': -0.23233942145478365,
#   'kurtosis': nan},
#  'nonparam_L5': {'count': 3,
#   'mean': 2.097554643018545,
#   'std': 1.6154352816298965,
#   'min': 0.3081978948282801,
#   'max': 4.222313723604705,
#   'median': 1.7621523106226504,
#   'q25': 1.0351751027254652,
#   'q75': 2.9922330171136777,
#   'iqr': 1.9570579143882125,
#   'mode': 0.3081978948282801,
#   'skewness': 0.7409342005002862,
#   'kurtosis': nan},
#  'nonparam_RA': {'count': 3,
#   'mean': 0.8247068734857962,
#   'std': 0.10022971124092317,
#   'min': 0.7023342093134759,
#   'max': 0.9478423041988504,
#   'median': 0.8239441069450623,
#   'q25': 0.763139158129269,
#   'q75': 0.8858932055719564,
#   'iqr': 0.12275404744268736,
#   'mode': 0.7023342093134759,
#   'skewness': 0.027960521728045924,
#   'kurtosis': nan},
#  'physical_activity_sedentary': {'count': 3,
#   'mean': 1036.126984126984,
#   'std': 121.4165094123263,
#   'min': 880.6666666666666,
#   'max': 1177.0,
#   'median': 1050.7142857142858,
#   'q25': 965.6904761904761,
#   'q75': 1113.857142857143,
#   'iqr': 148.16666666666674,
#   'mode': 880.6666666666666,
#   'skewness': -0.43718446365259495,
#   'kurtosis': nan},
#  'physical_activity_light': {'count': 3,
#   'mean': 0.37566137566137564,
#   'std': 0.17258736963280522,
#   'min': 0.14285714285714285,
#   'max': 0.5555555555555556,
#   'median': 0.42857142857142855,
#   'q25': 0.2857142857142857,
#   'q75': 0.4920634920634921,
#   'iqr': 0.2063492063492064,
#   'mode': 0.14285714285714285,
#   'skewness': -1.05583189396431,
#   'kurtosis': nan},
#  'physical_activity_moderate': {'count': 3,
#   'mean': 1.0687830687830686,
#   'std': 0.35689781913312274,
#   'min': 0.7777777777777778,
#   'max': 1.5714285714285714,
#   'median': 0.8571428571428571,
#   'q25': 0.8174603174603174,
#   'q75': 1.2142857142857142,
#   'iqr': 0.39682539682539675,
#   'mode': 0.7777777777777778,
#   'skewness': 1.6680336834432523,
#   'kurtosis': nan},
#  'physical_activity_vigorous': {'count': 3,
#   'mean': 402.4285714285714,
#   'std': 121.56199952242955,
#   'min': 261.2857142857143,
#   'max': 558.0,
#   'median': 388.0,
#   'q25': 324.6428571428571,
#   'q75': 473.0,
#   'iqr': 148.3571428571429,
#   'mode': 261.2857142857143,
#   'skewness': 0.43201039638340677,
#   'kurtosis': nan},
#  'sleep_TST': {'count': 3,
#   'mean': 930.4021164021165,
#   'std': 150.45639273985714,
#   'min': 762.7777777777778,
#   'max': 1127.7142857142858,
#   'median': 900.7142857142857,
#   'q25': 831.7460317460318,
#   'q75': 1014.2142857142858,
#   'iqr': 182.46825396825398,
#   'mode': 762.7777777777778,
#   'skewness': 0.7061762426149868,
#   'kurtosis': nan},
#  'sleep_WASO': {'count': 3,
#   'mean': 435.65608465608466,
#   'std': 93.42807372876418,
#   'min': 304.2857142857143,
#   'max': 513.5714285714286,
#   'median': 489.1111111111111,
#   'q25': 396.69841269841265,
#   'q75': 501.3412698412698,
#   'iqr': 104.64285714285717,
#   'mode': 304.2857142857143,
#   'skewness': -1.6434345234781906,
#   'kurtosis': nan},
#  'sleep_PTA': {'count': 3,
#   'mean': 64.61122222222222,
#   'std': 10.44841137004676,
#   'min': 52.970666666666666,
#   'max': 78.31357142857144,
#   'median': 62.54942857142857,
#   'q25': 57.76004761904762,
#   'q75': 70.4315,
#   'iqr': 12.671452380952381,
#   'mode': 52.970666666666666,
#   'skewness': 0.7062179844143968,
#   'kurtosis': nan},
#  'sleep_NWB': {'count': 3,
#   'mean': 20.85185185185185,
#   'std': 4.286426226058161,
#   'min': 15.285714285714286,
#   'max': 25.714285714285715,
#   'median': 21.555555555555557,
#   'q25': 18.42063492063492,
#   'q75': 23.634920634920636,
#   'iqr': 5.214285714285715,
#   'mode': 15.285714285714286,
#   'skewness': -0.5923618004517487,
#   'kurtosis': nan},
#  'sleep_SOL': {'count': 3,
#   'mean': 18.164021164021165,
#   'std': 8.413500344461116,
#   'min': 7.285714285714286,
#   'max': 27.77777777777778,
#   'median': 19.428571428571427,
#   'q25': 13.357142857142856,
#   'q75': 23.6031746031746,
#   'iqr': 10.246031746031745,
#   'mode': 7.285714285714286,
#   'skewness': -0.5439212180418068,
#   'kurtosis': nan},
#  'sleep_SRI': {'count': 3,
#   'mean': -3.7485614275051327,
#   'std': 12.884862867303557,
#   'min': -13.350320438576176,
#   'max': 14.464409808398699,
#   'median': -12.359773652337921,
#   'q25': -12.855047045457049,
#   'q75': 1.052318078030389,
#   'iqr': 13.907365123487438,
#   'mode': -13.350320438576176,
#   'skewness': 1.724376592689783,
#   'kurtosis': nan}}

# %%
bulk_features.get_failed_handlers()
# Out:
# []

# %%
bulk_features.get_summary_dataframe()
# Out:
#                         feature  count         mean         std         min  \
# 0                 cosinor_mesor      3    13.486108    4.452266    7.584048
# 1             cosinor_amplitude      3     6.699874    6.197654    1.981533
# 2             cosinor_acrophase      3    -0.703342    0.495790   -1.403190
# 3        cosinor_acrophase_time      3   161.194087  113.626587   72.515072
# 4                   nonparam_IS      3     0.119795    0.027014    0.082596
# 5                   nonparam_IV      3     1.141262    0.125322    0.978943
# 6                  nonparam_M10      3    22.319546    7.412312   13.015495
# 7                   nonparam_L5      3     2.097555    1.615435    0.308198
# 8                   nonparam_RA      3     0.824707    0.100230    0.702334
# 9   physical_activity_sedentary      3  1036.126984  121.416509  880.666667
# 10      physical_activity_light      3     0.375661    0.172587    0.142857
# 11   physical_activity_moderate      3     1.068783    0.356898    0.777778
# 12   physical_activity_vigorous      3   402.428571  121.562000  261.285714
# 13                    sleep_TST      3   930.402116  150.456393  762.777778
# 14                   sleep_WASO      3   435.656085   93.428074  304.285714
# 15                    sleep_PTA      3    64.611222   10.448411   52.970667
# 16                    sleep_NWB      3    20.851852    4.286426   15.285714
# 17                    sleep_SOL      3    18.164021    8.413500    7.285714
# 18                    sleep_SRI      3    -3.748561   12.884863  -13.350320
#
#             max       median         q25          q75         iqr        mode  \
# 0     18.336685    14.537591   11.060820    16.437138    5.376318    7.584048
# 1     15.455865     2.662223    2.321878     9.059044    6.737166    1.981533
# 2     -0.316407    -0.390428   -0.896809    -0.353418    0.543392   -1.403190
# 3    321.587573    89.479615   80.997343   205.533594  124.536251   72.515072
# 4      0.145931     0.130858    0.106727     0.138394    0.031667    0.082596
# 5      1.284048     1.160796    1.069869     1.222422    0.152553    0.978943
# 6     31.153622    22.789522   17.902509    26.971572    9.069063   13.015495
# 7      4.222314     1.762152    1.035175     2.992233    1.957058    0.308198
# 8      0.947842     0.823944    0.763139     0.885893    0.122754    0.702334
# 9   1177.000000  1050.714286  965.690476  1113.857143  148.166667  880.666667
# 10     0.555556     0.428571    0.285714     0.492063    0.206349    0.142857
# 11     1.571429     0.857143    0.817460     1.214286    0.396825    0.777778
# 12   558.000000   388.000000  324.642857   473.000000  148.357143  261.285714
# 13  1127.714286   900.714286  831.746032  1014.214286  182.468254  762.777778
# 14   513.571429   489.111111  396.698413   501.341270  104.642857  304.285714
# 15    78.313571    62.549429   57.760048    70.431500   12.671452   52.970667
# 16    25.714286    21.555556   18.420635    23.634921    5.214286   15.285714
# 17    27.777778    19.428571   13.357143    23.603175   10.246032    7.285714
# 18    14.464410   -12.359774  -12.855047     1.052318   13.907365  -13.350320
#
#     skewness  kurtosis
# 0  -0.835471       NaN
# 1   1.716394       NaN
# 2  -1.703139       NaN
# 3   1.703139       NaN
# 4  -1.336466       NaN
# 5  -0.563413       NaN
# 6  -0.232339       NaN
# 7   0.740934       NaN
# 8   0.027961       NaN
# 9  -0.437184       NaN
# 10 -1.055832       NaN
# 11  1.668034       NaN
# 12  0.432010       NaN
# 13  0.706176       NaN
# 14 -1.643435       NaN
# 15  0.706218       NaN
# 16 -0.592362       NaN
# 17 -0.543921       NaN
# 18  1.724377       NaN

# %%
bulk_features.get_feature_correlation_matrix()
# Out:
#                              cosinor_mesor  cosinor_amplitude  \
# cosinor_mesor                     1.000000           0.741003
# cosinor_amplitude                 0.741003           1.000000
# cosinor_acrophase                -0.226781           0.485961
# cosinor_acrophase_time            0.226781          -0.485961
# nonparam_IS                      -0.387199           0.332207
# nonparam_IV                      -0.449544          -0.932938
# nonparam_M10                      0.992453           0.817753
# nonparam_L5                       0.517594          -0.191017
# nonparam_RA                      -0.641738           0.039462
# physical_activity_sedentary      -0.569851           0.129544
# physical_activity_light           0.789438           0.172788
# physical_activity_moderate       -0.901866          -0.378186
# physical_activity_vigorous        0.570696          -0.128524
# sleep_TST                        -0.738850          -0.094985
# sleep_WASO                        0.969226           0.552894
# sleep_PTA                        -0.738856          -0.094994
# sleep_NWB                         0.998678           0.774546
# sleep_SOL                         0.715864           0.061587
# sleep_SRI                        -0.925967          -0.432583
#
#                              cosinor_acrophase  cosinor_acrophase_time  \
# cosinor_mesor                        -0.226781                0.226781
# cosinor_amplitude                     0.485961               -0.485961
# cosinor_acrophase                     1.000000               -1.000000
# cosinor_acrophase_time               -1.000000                1.000000
# nonparam_IS                           0.985784               -0.985784
# nonparam_IV                          -0.768037                0.768037
# nonparam_M10                         -0.105641                0.105641
# nonparam_L5                          -0.950714                0.950714
# nonparam_RA                           0.892477               -0.892477
# physical_activity_sedentary           0.929570               -0.929570
# physical_activity_light              -0.776867                0.776867
# physical_activity_moderate            0.625286               -0.625286
# physical_activity_vigorous           -0.929190                0.929190
# sleep_TST                             0.823870               -0.823870
# sleep_WASO                           -0.459561                0.459561
# sleep_PTA                             0.823865               -0.823865
# sleep_NWB                            -0.176410                0.176410
# sleep_SOL                            -0.842392                0.842392
# sleep_SRI                             0.577757               -0.577757
#
#                              nonparam_IS  nonparam_IV  nonparam_M10  \
# cosinor_mesor                  -0.387199    -0.449544      0.992453
# cosinor_amplitude               0.332207    -0.932938      0.817753
# cosinor_acrophase               0.985784    -0.768037     -0.105641
# cosinor_acrophase_time         -0.985784     0.768037      0.105641
# nonparam_IS                     1.000000    -0.649517     -0.271218
# nonparam_IV                    -0.649517     1.000000     -0.555686
# nonparam_M10                   -0.271218    -0.555686      1.000000
# nonparam_L5                    -0.989296     0.531614      0.408767
# nonparam_RA                     0.955581    -0.396572     -0.542852
# physical_activity_sedentary     0.978294    -0.477860     -0.464785
# physical_activity_light        -0.871619     0.193421      0.708210
# physical_activity_moderate      0.747518     0.019528     -0.842085
# physical_activity_vigorous     -0.978081     0.476956      0.465695
# sleep_TST                       0.907387    -0.269793     -0.650642
# sleep_WASO                     -0.602253    -0.215815      0.931725
# sleep_PTA                       0.907384    -0.269785     -0.650649
# sleep_NWB                      -0.339286    -0.494873      0.997445
# sleep_SOL                      -0.920956     0.301896      0.624840
# sleep_SRI                       0.706683     0.078966     -0.872676
#
#                              nonparam_L5  nonparam_RA  \
# cosinor_mesor                   0.517594    -0.641738
# cosinor_amplitude              -0.191017     0.039462
# cosinor_acrophase              -0.950714     0.892477
# cosinor_acrophase_time          0.950714    -0.892477
# nonparam_IS                    -0.989296     0.955581
# nonparam_IV                     0.531614    -0.396572
# nonparam_M10                    0.408767    -0.542852
# nonparam_L5                     1.000000    -0.988360
# nonparam_RA                    -0.988360     1.000000
# physical_activity_sedentary    -0.998061     0.995913
# physical_activity_light         0.933818    -0.977373
# physical_activity_moderate     -0.836444     0.910085
# physical_activity_vigorous      0.997996    -0.996006
# sleep_TST                      -0.959005     0.990955
# sleep_WASO                      0.712297    -0.810785
# sleep_PTA                      -0.959002     0.990954
# sleep_NWB                       0.472921    -0.601461
# sleep_SOL                       0.967959    -0.994894
# sleep_SRI                      -0.802362     0.883821
#
#                              physical_activity_sedentary  \
# cosinor_mesor                                  -0.569851
# cosinor_amplitude                               0.129544
# cosinor_acrophase                               0.929570
# cosinor_acrophase_time                         -0.929570
# nonparam_IS                                     0.978294
# nonparam_IV                                    -0.477860
# nonparam_M10                                   -0.464785
# nonparam_L5                                    -0.998061
# nonparam_RA                                     0.995913
# physical_activity_sedentary                     1.000000
# physical_activity_light                        -0.954276
# physical_activity_moderate                      0.868937
# physical_activity_vigorous                     -0.999999
# sleep_TST                                       0.974786
# sleep_WASO                                     -0.754606
# sleep_PTA                                       0.974784
# sleep_NWB                                      -0.526850
# sleep_SOL                                      -0.981713
# sleep_SRI                                       0.837958
#
#                              physical_activity_light  \
# cosinor_mesor                               0.789438
# cosinor_amplitude                           0.172788
# cosinor_acrophase                          -0.776867
# cosinor_acrophase_time                      0.776867
# nonparam_IS                                -0.871619
# nonparam_IV                                 0.193421
# nonparam_M10                                0.708210
# nonparam_L5                                 0.933818
# nonparam_RA                                -0.977373
# physical_activity_sedentary                -0.954276
# physical_activity_light                     1.000000
# physical_activity_moderate                 -0.977152
# physical_activity_vigorous                  0.954583
# sleep_TST                                  -0.996918
# sleep_WASO                                  0.916252
# sleep_PTA                                  -0.996919
# sleep_NWB                                   0.756836
# sleep_SOL                                   0.993731
# sleep_SRI                                  -0.962778
#
#                              physical_activity_moderate  \
# cosinor_mesor                                 -0.901866
# cosinor_amplitude                             -0.378186
# cosinor_acrophase                              0.625286
# cosinor_acrophase_time                        -0.625286
# nonparam_IS                                    0.747518
# nonparam_IV                                    0.019528
# nonparam_M10                                  -0.842085
# nonparam_L5                                   -0.836444
# nonparam_RA                                    0.910085
# physical_activity_sedentary                    0.868937
# physical_activity_light                       -0.977152
# physical_activity_moderate                     1.000000
# physical_activity_vigorous                    -0.869446
# sleep_TST                                      0.957466
# sleep_WASO                                    -0.980463
# sleep_PTA                                      0.957469
# sleep_NWB                                     -0.878463
# sleep_SOL                                     -0.947264
# sleep_SRI                                      0.998229
#
#                              physical_activity_vigorous  sleep_TST  \
# cosinor_mesor                                  0.570696  -0.738850
# cosinor_amplitude                             -0.128524  -0.094985
# cosinor_acrophase                             -0.929190   0.823870
# cosinor_acrophase_time                         0.929190  -0.823870
# nonparam_IS                                   -0.978081   0.907387
# nonparam_IV                                    0.476956  -0.269793
# nonparam_M10                                   0.465695  -0.650642
# nonparam_L5                                    0.997996  -0.959005
# nonparam_RA                                   -0.996006   0.990955
# physical_activity_sedentary                   -0.999999   0.974786
# physical_activity_light                        0.954583  -0.996918
# physical_activity_moderate                    -0.869446   0.957466
# physical_activity_vigorous                     1.000000  -0.975015
# sleep_TST                                     -0.975015   1.000000
# sleep_WASO                                     0.755281  -0.882001
# sleep_PTA                                     -0.975013   1.000000
# sleep_NWB                                      0.527725  -0.703229
# sleep_SOL                                      0.981908  -0.999439
# sleep_SRI                                     -0.838519   0.938607
#
#                              sleep_WASO  sleep_PTA  sleep_NWB  sleep_SOL  \
# cosinor_mesor                  0.969226  -0.738856   0.998678   0.715864
# cosinor_amplitude              0.552894  -0.094994   0.774546   0.061587
# cosinor_acrophase             -0.459561   0.823865  -0.176410  -0.842392
# cosinor_acrophase_time         0.459561  -0.823865   0.176410   0.842392
# nonparam_IS                   -0.602253   0.907384  -0.339286  -0.920956
# nonparam_IV                   -0.215815  -0.269785  -0.494873   0.301896
# nonparam_M10                   0.931725  -0.650649   0.997445   0.624840
# nonparam_L5                    0.712297  -0.959002   0.472921   0.967959
# nonparam_RA                   -0.810785   0.990954  -0.601461  -0.994894
# physical_activity_sedentary   -0.754606   0.974784  -0.526850  -0.981713
# physical_activity_light        0.916252  -0.996919   0.756836   0.993731
# physical_activity_moderate    -0.980463   0.957469  -0.878463  -0.947264
# physical_activity_vigorous     0.755281  -0.975013   0.527725   0.981908
# sleep_TST                     -0.882001   1.000000  -0.703229  -0.999439
# sleep_WASO                     1.000000  -0.882005   0.955288   0.865721
# sleep_PTA                     -0.882005   1.000000  -0.703235  -0.999439
# sleep_NWB                      0.955288  -0.703235   1.000000   0.679020
# sleep_SOL                      0.865721  -0.999439   0.679020   1.000000
# sleep_SRI                     -0.990427   0.938610  -0.905330  -0.926524
#
#                              sleep_SRI
# cosinor_mesor                -0.925967
# cosinor_amplitude            -0.432583
# cosinor_acrophase             0.577757
# cosinor_acrophase_time       -0.577757
# nonparam_IS                   0.706683
# nonparam_IV                   0.078966
# nonparam_M10                 -0.872676
# nonparam_L5                  -0.802362
# nonparam_RA                   0.883821
# physical_activity_sedentary   0.837958
# physical_activity_light      -0.962778
# physical_activity_moderate    0.998229
# physical_activity_vigorous   -0.838519
# sleep_TST                     0.938607
# sleep_WASO                   -0.990427
# sleep_PTA                     0.938610
# sleep_NWB                    -0.905330
# sleep_SOL                    -0.926524
# sleep_SRI                     1.000000
