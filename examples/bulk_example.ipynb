# %% [markdown]
# <div class="alert alert-block alert-success">
#  Bulk Feature Computation - Example
# </div>

# %%
from cosinorage.datahandlers import GenericDataHandler
from cosinorage.features import BulkWearableFeatures

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
preprocess_args = {
    'autocalib_sd_criter': 0.01,
    'autocalib_sphere_crit': 0.02,
    'filter_type': 'lowpass',
    'filter_cutoff': 2,
    'wear_sd_crit': 0.00013,
    'wear_range_crit': 0.00067,
    'wear_window_length': 45,
    'wear_window_skip': 7,
    'required_daily_coverage': 0.5
}

# %%
generic_handler1 = GenericDataHandler(file_path='../data/public data/processed/watch_acc/1155FF54-63D3-4AB2-9863-8385D0BD0A13_watch_acc.csv', 
                                            data_format='csv',
                                            data_type='accelerometer-mg',
                                            time_format='unix-s',
                                            time_column='timestamp',
                                            data_columns=['x', 'y', 'z'],
                                            preprocess_args=preprocess_args,
                                            verbose=True
                                            )

generic_handler2 = GenericDataHandler(file_path='../data/public data/processed/watch_acc/1DBB0F6F-1F81-4A50-9DF4-CD62ACFA4842_watch_acc.csv', 
                                            data_format='csv',
                                            data_type='accelerometer-mg',
                                            time_format='unix-s',
                                            time_column='timestamp',
                                            data_columns=['x', 'y', 'z'],
                                            preprocess_args=preprocess_args,
                                            verbose=True
                                            )

generic_handler3 = GenericDataHandler(file_path='../data/public data/processed/watch_acc/78A91A4E-4A51-4065-BDA7-94755F0BB3BB_watch_acc.csv', 
                                            data_format='csv',
                                            data_type='accelerometer-mg',
                                            time_format='unix-s',
                                            time_column='timestamp',
                                            data_columns=['x', 'y', 'z'],
                                            preprocess_args=preprocess_args,
                                            verbose=True
                                            )
# Out:
# Read csv file from ../data/public data/processed/watch_acc/1155FF54-63D3-4AB2-9863-8385D0BD0A13_watch_acc.csv
# Loaded 17681496 Count data records from ../data/public data/processed/watch_acc/1155FF54-63D3-4AB2-9863-8385D0BD0A13_watch_acc.csv
# Filtered out 2561496/17681496 accelerometer-mg records due to filtering out first and last day
# Filtered out 0/15120000 records due to incomplete daily coverage
# Filtered out 0/15120000 records due to filtering for longest consecutive sequence of days
# Filtered to ensure first day starts at 00:00 and last day ends at 23:59: 0/15120000 records removed
# Resampled 15120000 to 10080 timestamps
# Calibration done
# Noise removal done
# Wear detection done
# Wear time calculated
# Calculated ENMO for 10080 accelerometer records
# Preprocessed accelerometer-mg data
# __load_data executed in 21.48 seconds
# /Users/jacquesleooscar/Documents/Education/ETHZ/Curriculum/Semester04/04MasterThesis/CosinorAge/venvCL/lib/python3.10/site-packages/skdh/preprocessing/calibrate.py:163: UserWarning: Less than 72 hours of data (0.1119998936 hours). No Calibration performed
#   warn(
# Read csv file from ../data/public data/processed/watch_acc/1DBB0F6F-1F81-4A50-9DF4-CD62ACFA4842_watch_acc.csv
# Loaded 16642023 Count data records from ../data/public data/processed/watch_acc/1DBB0F6F-1F81-4A50-9DF4-CD62ACFA4842_watch_acc.csv
# Filtered out 1522023/16642023 accelerometer-mg records due to filtering out first and last day
# Filtered out 0/15120000 records due to incomplete daily coverage
# Filtered out 0/15120000 records due to filtering for longest consecutive sequence of days
# Filtered to ensure first day starts at 00:00 and last day ends at 23:59: 0/15120000 records removed
# Resampled 15120000 to 10080 timestamps
# Calibration done
# Noise removal done
# Wear detection done
# Wear time calculated
# Calculated ENMO for 10080 accelerometer records
# Preprocessed accelerometer-mg data
# __load_data executed in 20.20 seconds
# /Users/jacquesleooscar/Documents/Education/ETHZ/Curriculum/Semester04/04MasterThesis/CosinorAge/venvCL/lib/python3.10/site-packages/skdh/preprocessing/calibrate.py:163: UserWarning: Less than 72 hours of data (0.1119998936 hours). No Calibration performed
#   warn(
# Read csv file from ../data/public data/processed/watch_acc/78A91A4E-4A51-4065-BDA7-94755F0BB3BB_watch_acc.csv
# Loaded 20009272 Count data records from ../data/public data/processed/watch_acc/78A91A4E-4A51-4065-BDA7-94755F0BB3BB_watch_acc.csv
# Filtered out 569272/20009272 accelerometer-mg records due to filtering out first and last day
# Filtered out 0/19440000 records due to incomplete daily coverage
# Filtered out 0/19440000 records due to filtering for longest consecutive sequence of days
# Filtered to ensure first day starts at 00:00 and last day ends at 23:59: 0/19440000 records removed
# Resampled 19440000 to 12960 timestamps
# Calibration done
# Noise removal done
# Wear detection done
# Wear time calculated
# Calculated ENMO for 12960 accelerometer records
# Preprocessed accelerometer-mg data
# __load_data executed in 25.45 seconds
# /Users/jacquesleooscar/Documents/Education/ETHZ/Curriculum/Semester04/04MasterThesis/CosinorAge/venvCL/lib/python3.10/site-packages/skdh/preprocessing/calibrate.py:163: UserWarning: Less than 72 hours of data (0.1439998632 hours). No Calibration performed
#   warn(

# %%
features_args = {
    'sleep_ck_sf': 0.01,
    'sleep_rescore': True,
    'pa_cutpoint_sl': 15,
    'pa_cutpoint_lm': 35,
    'pa_cutpoint_mv': 70,
}

# %%
handlers = [generic_handler1, generic_handler2, generic_handler3]
cosinor_age_inputs = [{'gender': 'male', 'age': 20, 'gt_cosinor_age': 30}, {'gender': 'female', 'age': 20, 'gt_cosinor_age': 30}, {'gender': 'unknown', 'age': 20, 'gt_cosinor_age': 30}] 
bulk_features = BulkWearableFeatures(
    handlers=handlers, 
    features_args=features_args,
    cosinor_age_inputs=cosinor_age_inputs, 
    compute_distributions=True
    )

# %%
bulk_features.get_summary_dataframe()
# Out:
#                          feature  count         mean         std          min  \
# 0                  cosinor_mesor      3    12.305807    7.336767     3.826869
# 1              cosinor_amplitude      3     4.236227    3.887538     0.743088
# 2              cosinor_acrophase      3    -3.040059    1.977917    -4.442719
# 3         cosinor_acrophase_time      3   696.730301  453.305269    55.660744
# 4                    nonparam_IS      3     0.102678    0.042528     0.043719
# 5                    nonparam_IV      3     1.229291    0.103110     1.092402
# 6                   nonparam_M10      3    21.213559   12.626639     7.272428
# 7                    nonparam_L5      3     1.002035    0.757173     0.142060
# 8                    nonparam_RA      3     0.919303    0.044998     0.857062
# 9    physical_activity_sedentary      3  1170.687831   97.831862  1074.777778
# 10       physical_activity_light      3   121.402116   40.032582    88.714286
# 11    physical_activity_moderate      3   101.582011   59.856532    22.857143
# 12    physical_activity_vigorous      3    46.328042   41.540105    14.428571
# 13                     sleep_TST      3   938.322751  158.263172   804.285714
# 14                    sleep_WASO      3   428.492063  137.999553   272.857143
# 15                     sleep_PTA      3    65.161376   10.990478    55.853286
# 16                     sleep_NWB      3    16.857143    7.587136    11.000000
# 17                     sleep_SOL      3    18.687831   16.377396     5.571429
# 18                     sleep_SRI      3    -0.847517   13.445428   -11.903107
# 19                    cosinorage      3    33.555780    2.997899    30.990195
# 20            cosinorage_advance      3    13.555780    2.997899    10.990195
# 21  cosinor_age_prediction_error      3     3.555780    2.997899     0.990195
#
#             max       median          q25          q75         iqr  \
# 0     21.724362    11.366191     7.596530    16.545276    8.948746
# 1      9.659469     2.306124     1.524606     5.982796    4.458190
# 2     -0.242866    -4.434594    -4.438656    -2.338730    2.099927
# 3   1018.196162  1016.333998   535.997371  1017.265080  481.267709
# 4      0.142447     0.121867     0.082793     0.132157    0.049364
# 5      1.341251     1.254219     1.173310     1.297735    0.124425
# 6     37.847543    18.520707    12.896568    28.184125   15.287557
# 7      1.984562     0.879484     0.510772     1.432023    0.921251
# 8      0.961906     0.938939     0.898001     0.950423    0.052422
# 9   1305.000000  1132.285714  1103.531746  1218.642857  115.111111
# 10   177.777778    97.714286    93.214286   137.746032   44.531746
# 11   167.888889   114.000000    68.428571   140.944444   72.515873
# 12   105.000000    19.555556    16.992063    62.277778   45.285714
# 13  1160.571429   850.111111   827.198413  1005.341270  178.142857
# 14   608.285714   404.333333   338.595238   506.309524  167.714286
# 15    80.595286    59.035556    57.444421    69.815421   12.371000
# 16    27.571429    12.000000    11.500000    19.785714    8.285714
# 17    41.777778     8.714286     7.142857    25.246032   18.103175
# 18    18.078030    -8.717474   -10.310290     4.680278   14.990569
# 19    37.761657    31.915488    31.452841    34.838573    3.385731
# 20    17.761657    11.915488    11.452841    14.838573    3.385731
# 21     7.761657     1.915488     1.452841     4.838573    3.385731
#
#            mode  skewness
# 0      3.826869  0.465412
# 1      0.743088  1.524428
# 2     -4.442719  1.732029
# 3     55.660744 -1.732029
# 4      0.043719 -1.432861
# 5      1.092402 -0.853673
# 6      7.272428  0.759835
# 7      0.142060  0.584302
# 8      0.857062 -1.399843
# 9   1074.777778  1.294104
# 10    88.714286  1.666625
# 11    22.857143 -0.740394
# 12    14.428571  1.712283
# 13   804.285714  1.623775
# 14   272.857143  0.630083
# 15    55.853286  1.623778
# 16    11.000000  1.709511
# 17     5.571429  1.684334
# 18   -11.903107  1.659413
# 19    30.990195  1.609122
# 20    10.990195  1.609122
# 21     0.990195  1.609122

# %%
bulk_features.get_individual_features()
# Out:
# [{'cosinor': {'mesor': np.float64(21.724361540289184),
#    'amplitude': np.float64(9.659468598011658),
#    'acrophase': np.float64(-4.43459364125009),
#    'acrophase_time': 1016.333997996728},
#   'nonparam': {'IS': 0.14244684632705196,
#    'IV': 1.341251338796505,
#    'M10': [13.144984687703836,
#     22.471180899365763,
#     19.287971069879312,
#     27.89764111333781,
#     76.30425593467706,
#     37.2677155217937,
#     68.5590525458833],
#    'M10_start': [Timestamp('2016-05-27 00:00:00'),
#     Timestamp('2016-05-28 00:43:00'),
#     Timestamp('2016-05-29 00:00:00'),
#     Timestamp('2016-05-30 02:02:00'),
#     Timestamp('2016-05-31 13:02:00'),
#     Timestamp('2016-06-01 11:46:00'),
#     Timestamp('2016-06-02 13:25:00')],
#    'L5': [4.9016168411847225,
#     1.6152449683072916,
#     0.33753146234380677,
#     0.22692135883412234,
#     0.0,
#     4.004250667153985,
#     2.8063653900765564],
#    'L5_start': [Timestamp('2016-05-27 12:40:00'),
#     Timestamp('2016-05-28 14:36:00'),
#     Timestamp('2016-05-29 05:48:00'),
#     Timestamp('2016-05-30 11:50:00'),
#     Timestamp('2016-05-31 04:57:00'),
#     Timestamp('2016-06-01 05:41:00'),
#     Timestamp('2016-06-02 06:12:00')],
#    'RA': [0.4567822829868179,
#     0.8658792319639961,
#     0.9656027699887313,
#     0.9838631190043471,
#     1.0,
#     0.8059578432090163,
#     0.9213522327412177]},
#   'physical_activity': {'sedentary': [1150,
#     1190,
#     1132,
#     1163,
#     1184,
#     1037,
#     1070],
#    'light': [117, 90, 87, 106, 80, 96, 45],
#    'moderate': [138, 77, 107, 104, 72, 195, 105],
#    'vigorous': [35, 83, 114, 67, 104, 112, 220]},
#   'sleep': {'TST': [743, 849, 773, 857, 981, 681, 746],
#    'WASO': [681, 590, 645, 573, 459, 756, 554],
#    'PTA': [51.597, 58.958, 53.681, 59.514, 68.125, 47.292, 51.806],
#    'NWB': [42, 29, 24, 24, 14, 29, 31],
#    'SOL': [16, 0, 8, 10, 0, 3, 24],
#    'SRI': -11.903107316588901,
#    'SRI_flag': 'negative SRI - very low sleep consistency'},
#   'cosinorage': {'cosinorage': 30.990194524554298,
#    'cosinorage_advance': 10.990194524554298,
#    'cosinor_age_prediction_error': 0.9901945245542976}},
#  {'cosinor': {'mesor': np.float64(3.8268692761371934),
#    'amplitude': np.float64(2.30612434023714),
#    'acrophase': np.float64(-4.442718866100984),
#    'acrophase_time': 1018.1961623629322},
#   'nonparam': {'IS': 0.1218672968161118,
#    'IV': 1.2542185805941028,
#    'M10': [9.494056598153133,
#     2.2506655142951413,
#     7.171964076893129,
#     2.8241786504546447,
#     8.538988962328194,
#     18.007128590482843,
#     2.620016343026416],
#    'M10_start': [Timestamp('2015-08-27 10:08:00'),
#     Timestamp('2015-08-28 13:40:00'),
#     Timestamp('2015-08-29 00:07:00'),
#     Timestamp('2015-08-30 00:11:00'),
#     Timestamp('2015-08-31 13:40:00'),
#     Timestamp('2015-09-01 09:19:00'),
#     Timestamp('2015-09-02 00:12:00')],
#    'L5': [0.0,
#     0.0,
#     0.3244509137721192,
#     0.0,
#     0.28058819073374375,
#     0.2703998860805272,
#     0.1189840978481323],
#    'L5_start': [Timestamp('2015-08-27 02:24:00'),
#     Timestamp('2015-08-28 00:00:00'),
#     Timestamp('2015-08-29 09:09:00'),
#     Timestamp('2015-08-30 10:11:00'),
#     Timestamp('2015-08-31 06:49:00'),
#     Timestamp('2015-09-01 04:12:00'),
#     Timestamp('2015-09-02 10:18:00')],
#    'RA': [1.0,
#     1.0,
#     0.9134383797652252,
#     1.0,
#     0.9363715094580628,
#     0.9704117669489888,
#     0.9131185989804795]},
#   'physical_activity': {'sedentary': [1244,
#     1426,
#     1312,
#     1378,
#     1364,
#     1014,
#     1397],
#    'light': [124, 10, 77, 35, 18, 397, 23],
#    'moderate': [54, 1, 37, 20, 15, 19, 14],
#    'vigorous': [18, 3, 14, 7, 43, 10, 6]},
#   'sleep': {'TST': [1054, 1311, 1124, 1267, 1248, 887, 1233],
#    'WASO': [350, 129, 309, 170, 192, 553, 207],
#    'PTA': [73.194, 91.042, 78.056, 87.986, 86.667, 61.597, 85.625],
#    'NWB': [10, 2, 17, 8, 12, 12, 16],
#    'SOL': [36, 0, 0, 3, 0, 0, 0],
#    'SRI': 18.078030378238864},
#   'cosinorage': {'cosinorage': 37.7616574519855,
#    'cosinorage_advance': 17.7616574519855,
#    'cosinor_age_prediction_error': 7.761657451985499}},
#  {'cosinor': {'mesor': np.float64(11.36619064698666),
#    'amplitude': np.float64(0.7430883760248588),
#    'acrophase': np.float64(-0.24286581008871266),
#    'acrophase_time': 55.66074362443608},
#   'nonparam': {'IS': 0.04371850302438376,
#    'IV': 1.092401861719797,
#    'M10': [33.371083836208825,
#     8.98453020684034,
#     5.754747534722776,
#     39.937883290823294,
#     35.31134129468908,
#     14.050060466674143,
#     0.5071280828435598,
#     3.1511967198388966,
#     25.618391440178517],
#    'M10_start': [Timestamp('2015-12-02 00:00:00'),
#     Timestamp('2015-12-03 13:22:00'),
#     Timestamp('2015-12-04 06:00:00'),
#     Timestamp('2015-12-05 08:52:00'),
#     Timestamp('2015-12-06 12:12:00'),
#     Timestamp('2015-12-07 01:49:00'),
#     Timestamp('2015-12-08 08:13:00'),
#     Timestamp('2015-12-09 06:34:00'),
#     Timestamp('2015-12-10 03:11:00')],
#    'L5': [0.0,
#     0.06995612364111503,
#     0.2731825578131793,
#     1.512108461880588,
#     3.451077653971091,
#     0.0985708660101096,
#     0.0,
#     0.0,
#     2.510461756493295],
#    'L5_start': [Timestamp('2015-12-02 09:50:00'),
#     Timestamp('2015-12-03 06:27:00'),
#     Timestamp('2015-12-04 18:06:00'),
#     Timestamp('2015-12-05 00:00:00'),
#     Timestamp('2015-12-06 02:37:00'),
#     Timestamp('2015-12-07 17:41:00'),
#     Timestamp('2015-12-08 00:00:00'),
#     Timestamp('2015-12-09 00:00:00'),
#     Timestamp('2015-12-10 18:36:00')],
#    'RA': [1.0,
#     0.9845477432760352,
#     0.9093610729986914,
#     0.9270393841860319,
#     0.8219369302755871,
#     0.9860663743803395,
#     1.0,
#     1.0,
#     0.8215027296747148]},
#   'physical_activity': {'sedentary': [1064,
#     1070,
#     1360,
#     448,
#     864,
#     1203,
#     1434,
#     1381,
#     849],
#    'light': [118, 340, 58, 537, 147, 94, 2, 47, 257],
#    'moderate': [166, 30, 14, 426, 417, 141, 4, 12, 301],
#    'vigorous': [92, 0, 8, 29, 12, 2, 0, 0, 33]},
#   'sleep': {'TST': [819, 780, 858, 343, 609, 924, 1401, 1293, 624],
#    'WASO': [436, 323, 479, 170, 713, 516, 39, 147, 816],
#    'PTA': [56.875,
#     54.167,
#     59.583,
#     23.819,
#     42.292,
#     64.167,
#     97.292,
#     89.792,
#     43.333],
#    'NWB': [12, 5, 18, 6, 20, 27, 1, 7, 12],
#    'SOL': [38, 106, 100, 14, 118, 0, 0, 0, 0],
#    'SRI': -8.717473554165707,
#    'SRI_flag': 'negative SRI - very low sleep consistency'},
#   'cosinorage': {'cosinorage': 31.915488072385116,
#    'cosinorage_advance': 11.915488072385116,
#    'cosinor_age_prediction_error': 1.9154880723851164}}]

# %%
bulk_features.get_distribution_stats()
# Out:
# {'cosinor_mesor': {'count': 3,
#   'mean': 12.305807154471012,
#   'std': 7.336766623074859,
#   'min': 3.8268692761371934,
#   'max': 21.724361540289184,
#   'median': 11.36619064698666,
#   'q25': 7.596529961561926,
#   'q75': 16.545276093637924,
#   'iqr': 8.948746132075996,
#   'mode': 3.8268692761371934,
#   'skewness': 0.46541229525846084},
#  'cosinor_amplitude': {'count': 3,
#   'mean': 4.236227104757886,
#   'std': 3.887538345102833,
#   'min': 0.7430883760248588,
#   'max': 9.659468598011658,
#   'median': 2.30612434023714,
#   'q25': 1.5246063581309994,
#   'q75': 5.982796469124399,
#   'iqr': 4.4581901109933995,
#   'mode': 0.7430883760248588,
#   'skewness': 1.5244275125195668},
#  'cosinor_acrophase': {'count': 3,
#   'mean': -3.040059439146596,
#   'std': 1.9779173649154684,
#   'min': -4.442718866100984,
#   'max': -0.24286581008871266,
#   'median': -4.43459364125009,
#   'q25': -4.438656253675537,
#   'q75': -2.3387297256694013,
#   'iqr': 2.099926528006136,
#   'mode': -4.442718866100984,
#   'skewness': 1.7320288857860309},
#  'cosinor_acrophase_time': {'count': 3,
#   'mean': 696.7303013280322,
#   'std': 453.30526894117384,
#   'min': 55.66074362443608,
#   'max': 1018.1961623629322,
#   'median': 1016.333997996728,
#   'q25': 535.9973708105821,
#   'q75': 1017.2650801798302,
#   'iqr': 481.2677093692481,
#   'mode': 55.66074362443608,
#   'skewness': -1.73202888578603},
#  'nonparam_IS': {'count': 3,
#   'mean': 0.10267754872251583,
#   'std': 0.04252847098704686,
#   'min': 0.04371850302438376,
#   'max': 0.14244684632705196,
#   'median': 0.1218672968161118,
#   'q25': 0.08279289992024778,
#   'q75': 0.13215707157158188,
#   'iqr': 0.049364171651334096,
#   'mode': 0.04371850302438376,
#   'skewness': -1.4328606573667566},
#  'nonparam_IV': {'count': 3,
#   'mean': 1.2292905937034682,
#   'std': 0.10311019658001011,
#   'min': 1.092401861719797,
#   'max': 1.341251338796505,
#   'median': 1.2542185805941028,
#   'q25': 1.17331022115695,
#   'q75': 1.2977349596953038,
#   'iqr': 0.1244247385383539,
#   'mode': 1.092401861719797,
#   'skewness': -0.8536728488647012},
#  'nonparam_M10': {'count': 3,
#   'mean': 21.213559495683622,
#   'std': 12.626638534159074,
#   'min': 7.2724283908047855,
#   'max': 37.84754311037726,
#   'median': 18.520706985868827,
#   'q25': 12.896567688336805,
#   'q75': 28.184125048123043,
#   'iqr': 15.287557359786238,
#   'mode': 7.2724283908047855,
#   'skewness': 0.7598348860338331},
#  'nonparam_L5': {'count': 3,
#   'mean': 1.002035375268152,
#   'std': 0.7571731036469228,
#   'min': 0.14206044120493178,
#   'max': 1.9845615268429266,
#   'median': 0.8794841577565975,
#   'q25': 0.5107722994807646,
#   'q75': 1.432022842299762,
#   'iqr': 0.9212505428189974,
#   'mode': 0.14206044120493178,
#   'skewness': 0.5843023478555623},
#  'nonparam_RA': {'count': 3,
#   'mean': 0.9193025357617023,
#   'std': 0.044998004321489295,
#   'min': 0.8570624971277325,
#   'max': 0.9619057507361081,
#   'median': 0.9389393594212666,
#   'q25': 0.8980009282744996,
#   'q75': 0.9504225550786873,
#   'iqr': 0.052421626804187715,
#   'mode': 0.8570624971277325,
#   'skewness': -1.3998430106902198},
#  'physical_activity_sedentary': {'count': 3,
#   'mean': 1170.6878306878307,
#   'std': 97.83186191746135,
#   'min': 1074.7777777777778,
#   'max': 1305.0,
#   'median': 1132.2857142857142,
#   'q25': 1103.531746031746,
#   'q75': 1218.642857142857,
#   'iqr': 115.11111111111109,
#   'mode': 1074.7777777777778,
#   'skewness': 1.2941044243077946},
#  'physical_activity_light': {'count': 3,
#   'mean': 121.40211640211639,
#   'std': 40.03258170255347,
#   'min': 88.71428571428571,
#   'max': 177.77777777777777,
#   'median': 97.71428571428571,
#   'q25': 93.21428571428571,
#   'q75': 137.74603174603175,
#   'iqr': 44.53174603174604,
#   'mode': 88.71428571428571,
#   'skewness': 1.6666249114685265},
#  'physical_activity_moderate': {'count': 3,
#   'mean': 101.58201058201058,
#   'std': 59.85653228146556,
#   'min': 22.857142857142858,
#   'max': 167.88888888888889,
#   'median': 114.0,
#   'q25': 68.42857142857143,
#   'q75': 140.94444444444446,
#   'iqr': 72.51587301587303,
#   'mode': 22.857142857142858,
#   'skewness': -0.7403938004118515},
#  'physical_activity_vigorous': {'count': 3,
#   'mean': 46.32804232804233,
#   'std': 41.54010475315456,
#   'min': 14.428571428571429,
#   'max': 105.0,
#   'median': 19.555555555555557,
#   'q25': 16.992063492063494,
#   'q75': 62.27777777777778,
#   'iqr': 45.285714285714285,
#   'mode': 14.428571428571429,
#   'skewness': 1.712283354104868},
#  'sleep_TST': {'count': 3,
#   'mean': 938.3227513227515,
#   'std': 158.26317249577536,
#   'min': 804.2857142857143,
#   'max': 1160.5714285714287,
#   'median': 850.1111111111111,
#   'q25': 827.1984126984128,
#   'q75': 1005.3412698412699,
#   'iqr': 178.1428571428571,
#   'mode': 804.2857142857143,
#   'skewness': 1.6237752773782257},
#  'sleep_WASO': {'count': 3,
#   'mean': 428.49206349206344,
#   'std': 137.9995526920645,
#   'min': 272.85714285714283,
#   'max': 608.2857142857143,
#   'median': 404.3333333333333,
#   'q25': 338.5952380952381,
#   'q75': 506.30952380952385,
#   'iqr': 167.71428571428578,
#   'mode': 272.85714285714283,
#   'skewness': 0.6300834779587682},
#  'sleep_PTA': {'count': 3,
#   'mean': 65.16137566137566,
#   'std': 10.990477544269925,
#   'min': 55.85328571428572,
#   'max': 80.59528571428571,
#   'median': 59.03555555555556,
#   'q25': 57.44442063492064,
#   'q75': 69.81542063492063,
#   'iqr': 12.370999999999988,
#   'mode': 55.85328571428572,
#   'skewness': 1.6237782155232285},
#  'sleep_NWB': {'count': 3,
#   'mean': 16.857142857142858,
#   'std': 7.587135549753948,
#   'min': 11.0,
#   'max': 27.571428571428573,
#   'median': 12.0,
#   'q25': 11.5,
#   'q75': 19.785714285714285,
#   'iqr': 8.285714285714285,
#   'mode': 11.0,
#   'skewness': 1.7095114459198943},
#  'sleep_SOL': {'count': 3,
#   'mean': 18.687830687830687,
#   'std': 16.377395605274955,
#   'min': 5.571428571428571,
#   'max': 41.77777777777778,
#   'median': 8.714285714285714,
#   'q25': 7.142857142857142,
#   'q75': 25.246031746031747,
#   'iqr': 18.103174603174605,
#   'mode': 5.571428571428571,
#   'skewness': 1.6843343922481},
#  'sleep_SRI': {'count': 3,
#   'mean': -0.8475168308385813,
#   'std': 13.445428429751056,
#   'min': -11.903107316588901,
#   'max': 18.078030378238864,
#   'median': -8.717473554165707,
#   'q25': -10.310290435377304,
#   'q75': 4.680278412036579,
#   'iqr': 14.990568847413883,
#   'mode': -11.903107316588901,
#   'skewness': 1.6594127491865325},
#  'cosinorage': {'count': 3,
#   'mean': 33.555780016308304,
#   'std': 2.997898796420394,
#   'min': 30.990194524554298,
#   'max': 37.7616574519855,
#   'median': 31.915488072385116,
#   'q25': 31.452841298469707,
#   'q75': 34.83857276218531,
#   'iqr': 3.385731463715601,
#   'mode': 30.990194524554298,
#   'skewness': 1.6091220181808346},
#  'cosinorage_advance': {'count': 3,
#   'mean': 13.555780016308304,
#   'std': 2.997898796420394,
#   'min': 10.990194524554298,
#   'max': 17.7616574519855,
#   'median': 11.915488072385116,
#   'q25': 11.452841298469707,
#   'q75': 14.838572762185308,
#   'iqr': 3.385731463715601,
#   'mode': 10.990194524554298,
#   'skewness': 1.6091220181808346},
#  'cosinor_age_prediction_error': {'count': 3,
#   'mean': 3.5557800163083044,
#   'std': 2.997898796420394,
#   'min': 0.9901945245542976,
#   'max': 7.761657451985499,
#   'median': 1.9154880723851164,
#   'q25': 1.452841298469707,
#   'q75': 4.838572762185308,
#   'iqr': 3.385731463715601,
#   'mode': 0.9901945245542976,
#   'skewness': 1.6091220181808346}}

# %%
bulk_features.get_failed_handlers()
# Out:
# []

# %%
bulk_features.get_summary_dataframe()
# Out:
#                          feature  count         mean         std          min  \
# 0                  cosinor_mesor      3    12.305807    7.336767     3.826869
# 1              cosinor_amplitude      3     4.236227    3.887538     0.743088
# 2              cosinor_acrophase      3    -3.040059    1.977917    -4.442719
# 3         cosinor_acrophase_time      3   696.730301  453.305269    55.660744
# 4                    nonparam_IS      3     0.102678    0.042528     0.043719
# 5                    nonparam_IV      3     1.229291    0.103110     1.092402
# 6                   nonparam_M10      3    21.213559   12.626639     7.272428
# 7                    nonparam_L5      3     1.002035    0.757173     0.142060
# 8                    nonparam_RA      3     0.919303    0.044998     0.857062
# 9    physical_activity_sedentary      3  1170.687831   97.831862  1074.777778
# 10       physical_activity_light      3   121.402116   40.032582    88.714286
# 11    physical_activity_moderate      3   101.582011   59.856532    22.857143
# 12    physical_activity_vigorous      3    46.328042   41.540105    14.428571
# 13                     sleep_TST      3   938.322751  158.263172   804.285714
# 14                    sleep_WASO      3   428.492063  137.999553   272.857143
# 15                     sleep_PTA      3    65.161376   10.990478    55.853286
# 16                     sleep_NWB      3    16.857143    7.587136    11.000000
# 17                     sleep_SOL      3    18.687831   16.377396     5.571429
# 18                     sleep_SRI      3    -0.847517   13.445428   -11.903107
# 19                    cosinorage      3    33.555780    2.997899    30.990195
# 20            cosinorage_advance      3    13.555780    2.997899    10.990195
# 21  cosinor_age_prediction_error      3     3.555780    2.997899     0.990195
#
#             max       median          q25          q75         iqr  \
# 0     21.724362    11.366191     7.596530    16.545276    8.948746
# 1      9.659469     2.306124     1.524606     5.982796    4.458190
# 2     -0.242866    -4.434594    -4.438656    -2.338730    2.099927
# 3   1018.196162  1016.333998   535.997371  1017.265080  481.267709
# 4      0.142447     0.121867     0.082793     0.132157    0.049364
# 5      1.341251     1.254219     1.173310     1.297735    0.124425
# 6     37.847543    18.520707    12.896568    28.184125   15.287557
# 7      1.984562     0.879484     0.510772     1.432023    0.921251
# 8      0.961906     0.938939     0.898001     0.950423    0.052422
# 9   1305.000000  1132.285714  1103.531746  1218.642857  115.111111
# 10   177.777778    97.714286    93.214286   137.746032   44.531746
# 11   167.888889   114.000000    68.428571   140.944444   72.515873
# 12   105.000000    19.555556    16.992063    62.277778   45.285714
# 13  1160.571429   850.111111   827.198413  1005.341270  178.142857
# 14   608.285714   404.333333   338.595238   506.309524  167.714286
# 15    80.595286    59.035556    57.444421    69.815421   12.371000
# 16    27.571429    12.000000    11.500000    19.785714    8.285714
# 17    41.777778     8.714286     7.142857    25.246032   18.103175
# 18    18.078030    -8.717474   -10.310290     4.680278   14.990569
# 19    37.761657    31.915488    31.452841    34.838573    3.385731
# 20    17.761657    11.915488    11.452841    14.838573    3.385731
# 21     7.761657     1.915488     1.452841     4.838573    3.385731
#
#            mode  skewness
# 0      3.826869  0.465412
# 1      0.743088  1.524428
# 2     -4.442719  1.732029
# 3     55.660744 -1.732029
# 4      0.043719 -1.432861
# 5      1.092402 -0.853673
# 6      7.272428  0.759835
# 7      0.142060  0.584302
# 8      0.857062 -1.399843
# 9   1074.777778  1.294104
# 10    88.714286  1.666625
# 11    22.857143 -0.740394
# 12    14.428571  1.712283
# 13   804.285714  1.623775
# 14   272.857143  0.630083
# 15    55.853286  1.623778
# 16    11.000000  1.709511
# 17     5.571429  1.684334
# 18   -11.903107  1.659413
# 19    30.990195  1.609122
# 20    10.990195  1.609122
# 21     0.990195  1.609122

# %%
bulk_features.get_feature_correlation_matrix()
# Out:
#                               cosinor_mesor  cosinor_amplitude  \
# cosinor_mesor                      1.000000           0.826574
# cosinor_amplitude                  0.826574           1.000000
# cosinor_acrophase                 -0.088889          -0.634073
# cosinor_acrophase_time             0.088889           0.634073
# nonparam_IS                        0.285514           0.775399
# nonparam_IV                        0.428189           0.862551
# nonparam_M10                       0.998158           0.859193
# nonparam_L5                        0.999712           0.839851
# nonparam_RA                       -0.975235          -0.930584
# physical_activity_sedentary       -0.654991          -0.116105
# physical_activity_light           -0.181581          -0.703562
# physical_activity_moderate         0.548145          -0.017657
# physical_activity_vigorous         0.927732           0.976913
# sleep_TST                         -0.879590          -0.459291
# sleep_WASO                         0.999441           0.844921
# sleep_PTA                         -0.879590          -0.459290
# sleep_NWB                          0.929005           0.976176
# sleep_SOL                         -0.012259          -0.572919
# sleep_SRI                         -0.869106          -0.439991
# cosinorage                        -0.883300          -0.466254
# cosinorage_advance                -0.883300          -0.466254
# cosinor_age_prediction_error      -0.883300          -0.466254
#
#                               cosinor_acrophase  cosinor_acrophase_time  \
# cosinor_mesor                         -0.088889                0.088889
# cosinor_amplitude                     -0.634073                0.634073
# cosinor_acrophase                      1.000000               -1.000000
# cosinor_acrophase_time                -1.000000                1.000000
# nonparam_IS                           -0.979960                0.979960
# nonparam_IV                           -0.938173                0.938173
# nonparam_M10                          -0.149145                0.149145
# nonparam_L5                           -0.112782                0.112782
# nonparam_RA                            0.306981               -0.306981
# physical_activity_sedentary           -0.694424                0.694424
# physical_activity_light                0.995624               -0.995624
# physical_activity_moderate             0.784348               -0.784348
# physical_activity_vigorous            -0.454235                0.454235
# sleep_TST                             -0.395663                0.395663
# sleep_WASO                            -0.122124                0.122124
# sleep_PTA                             -0.395665                0.395665
# sleep_NWB                             -0.451181                0.451181
# sleep_SOL                              0.997056               -0.997056
# sleep_SRI                             -0.415414                0.415414
# cosinorage                            -0.388437                0.388437
# cosinorage_advance                    -0.388437                0.388437
# cosinor_age_prediction_error          -0.388437                0.388437
#
#                               nonparam_IS  nonparam_IV  nonparam_M10  \
# cosinor_mesor                    0.285514     0.428189      0.998158
# cosinor_amplitude                0.775399     0.862551      0.859193
# cosinor_acrophase               -0.979960    -0.938173     -0.149145
# cosinor_acrophase_time           0.979960     0.938173      0.149145
# nonparam_IS                      1.000000     0.988327      0.343123
# nonparam_IV                      0.988327     1.000000      0.482218
# nonparam_M10                     0.343123     0.482218      1.000000
# nonparam_L5                      0.308446     0.449766      0.999327
# nonparam_RA                     -0.490406    -0.617453     -0.986856
# physical_activity_sedentary      0.537174     0.402401     -0.607948
# physical_activity_light         -0.994286    -0.966417     -0.240898
# physical_activity_moderate      -0.645065    -0.521121      0.496401
# physical_activity_vigorous       0.622592     0.734544      0.948665
# sleep_TST                        0.204794     0.053283     -0.849113
# sleep_WASO                       0.317381     0.458149      0.999628
# sleep_PTA                        0.204795     0.053285     -0.849112
# sleep_NWB                        0.619907     0.732215      0.949742
# sleep_SOL                       -0.961803    -0.908870     -0.072892
# sleep_SRI                        0.225894     0.074846     -0.837502
# cosinorage                       0.197100     0.045438     -0.853235
# cosinorage_advance               0.197100     0.045438     -0.853235
# cosinor_age_prediction_error     0.197100     0.045438     -0.853235
#
#                               nonparam_L5  nonparam_RA  \
# cosinor_mesor                    0.999712    -0.975235
# cosinor_amplitude                0.839851    -0.930584
# cosinor_acrophase               -0.112782     0.306981
# cosinor_acrophase_time           0.112782    -0.306981
# nonparam_IS                      0.308446    -0.490406
# nonparam_IV                      0.449766    -0.617453
# nonparam_M10                     0.999327    -0.986856
# nonparam_L5                      1.000000    -0.980265
# nonparam_RA                     -0.980265     1.000000
# physical_activity_sedentary     -0.636657     0.471647
# physical_activity_light         -0.205143     0.394576
# physical_activity_moderate       0.527903    -0.349589
# physical_activity_vigorous       0.936427    -0.987308
# sleep_TST                       -0.867913     0.752591
# sleep_WASO                       0.999956    -0.982082
# sleep_PTA                       -0.867912     0.752590
# sleep_NWB                        0.937624    -0.987846
# sleep_SOL                       -0.036267     0.233108
# sleep_SRI                       -0.856978     0.738187
# cosinorage                      -0.871787     0.757739
# cosinorage_advance              -0.871787     0.757739
# cosinor_age_prediction_error    -0.871787     0.757739
#
#                               physical_activity_sedentary  ...  \
# cosinor_mesor                                   -0.654991  ...
# cosinor_amplitude                               -0.116105  ...
# cosinor_acrophase                               -0.694424  ...
# cosinor_acrophase_time                           0.694424  ...
# nonparam_IS                                      0.537174  ...
# nonparam_IV                                      0.402401  ...
# nonparam_M10                                    -0.607948  ...
# nonparam_L5                                     -0.636657  ...
# nonparam_RA                                      0.471647  ...
# physical_activity_sedentary                      1.000000  ...
# physical_activity_light                         -0.624141  ...
# physical_activity_moderate                      -0.991032  ...
# physical_activity_vigorous                      -0.325617  ...
# sleep_TST                                        0.935604  ...
# sleep_WASO                                      -0.629374  ...
# sleep_PTA                                        0.935605  ...
# sleep_NWB                                       -0.328854  ...
# sleep_SOL                                       -0.747550  ...
# sleep_SRI                                        0.943014  ...
# cosinorage                                       0.932802  ...
# cosinorage_advance                               0.932802  ...
# cosinor_age_prediction_error                     0.932802  ...
#
#                               physical_activity_vigorous  sleep_TST  \
# cosinor_mesor                                   0.927732  -0.879590
# cosinor_amplitude                               0.976913  -0.459291
# cosinor_acrophase                              -0.454235  -0.395663
# cosinor_acrophase_time                          0.454235   0.395663
# nonparam_IS                                     0.622592   0.204794
# nonparam_IV                                     0.734544   0.053283
# nonparam_M10                                    0.948665  -0.849113
# nonparam_L5                                     0.936427  -0.867913
# nonparam_RA                                    -0.987308   0.752591
# physical_activity_sedentary                    -0.325617   0.935604
# physical_activity_light                        -0.535501  -0.308107
# physical_activity_moderate                      0.196354  -0.880037
# physical_activity_vigorous                      1.000000  -0.638458
# sleep_TST                                      -0.638458   1.000000
# sleep_WASO                                      0.939687  -0.863201
# sleep_PTA                                      -0.638457   1.000000
# sleep_NWB                                       0.999994  -0.641091
# sleep_SOL                                      -0.384592  -0.464913
# sleep_SRI                                      -0.621680   0.999767
# cosinorage                                     -0.644484   0.999969
# cosinorage_advance                             -0.644484   0.999969
# cosinor_age_prediction_error                   -0.644484   0.999969
#
#                               sleep_WASO  sleep_PTA  sleep_NWB  sleep_SOL  \
# cosinor_mesor                   0.999441  -0.879590   0.929005  -0.012259
# cosinor_amplitude               0.844921  -0.459290   0.976176  -0.572919
# cosinor_acrophase              -0.122124  -0.395665  -0.451181   0.997056
# cosinor_acrophase_time          0.122124   0.395665   0.451181  -0.997056
# nonparam_IS                     0.317381   0.204795   0.619907  -0.961803
# nonparam_IV                     0.458149   0.053285   0.732215  -0.908870
# nonparam_M10                    0.999628  -0.849112   0.949742  -0.072892
# nonparam_L5                     0.999956  -0.867912   0.937624  -0.036267
# nonparam_RA                    -0.982082   0.752590  -0.987846   0.233108
# physical_activity_sedentary    -0.629374   0.935605  -0.328854  -0.747550
# physical_activity_light        -0.214342  -0.308108  -0.532605   0.985528
# physical_activity_moderate      0.519889  -0.880038   0.199711   0.829601
# physical_activity_vigorous      0.939687  -0.638457   0.999994  -0.384592
# sleep_TST                      -0.863201   1.000000  -0.641091  -0.464913
# sleep_WASO                      1.000000  -0.863200   0.940853  -0.045667
# sleep_PTA                      -0.863200   1.000000  -0.641090  -0.464915
# sleep_NWB                       0.940853  -0.641090   1.000000  -0.381428
# sleep_SOL                      -0.045667  -0.464915  -0.381428   1.000000
# sleep_SRI                      -0.852091   0.999767  -0.624359  -0.483934
# cosinorage                     -0.867140   0.999969  -0.647099  -0.457945
# cosinorage_advance             -0.867140   0.999969  -0.647099  -0.457945
# cosinor_age_prediction_error   -0.867140   0.999969  -0.647099  -0.457945
#
#                               sleep_SRI  cosinorage  cosinorage_advance  \
# cosinor_mesor                 -0.869106   -0.883300           -0.883300
# cosinor_amplitude             -0.439991   -0.466254           -0.466254
# cosinor_acrophase             -0.415414   -0.388437           -0.388437
# cosinor_acrophase_time         0.415414    0.388437            0.388437
# nonparam_IS                    0.225894    0.197100            0.197100
# nonparam_IV                    0.074846    0.045438            0.045438
# nonparam_M10                  -0.837502   -0.853235           -0.853235
# nonparam_L5                   -0.856978   -0.871787           -0.871787
# nonparam_RA                    0.738187    0.757739            0.757739
# physical_activity_sedentary    0.943014    0.932802            0.932802
# physical_activity_light       -0.328590   -0.300625           -0.300625
# physical_activity_moderate    -0.890093   -0.876280           -0.876280
# physical_activity_vigorous    -0.621680   -0.644484           -0.644484
# sleep_TST                      0.999767    0.999969            0.999969
# sleep_WASO                    -0.852091   -0.867140           -0.867140
# sleep_PTA                      0.999767    0.999969            0.999969
# sleep_NWB                     -0.624359   -0.647099           -0.647099
# sleep_SOL                     -0.483934   -0.457945           -0.457945
# sleep_SRI                      1.000000    0.999566            0.999566
# cosinorage                     0.999566    1.000000            1.000000
# cosinorage_advance             0.999566    1.000000            1.000000
# cosinor_age_prediction_error   0.999566    1.000000            1.000000
#
#                               cosinor_age_prediction_error
# cosinor_mesor                                    -0.883300
# cosinor_amplitude                                -0.466254
# cosinor_acrophase                                -0.388437
# cosinor_acrophase_time                            0.388437
# nonparam_IS                                       0.197100
# nonparam_IV                                       0.045438
# nonparam_M10                                     -0.853235
# nonparam_L5                                      -0.871787
# nonparam_RA                                       0.757739
# physical_activity_sedentary                       0.932802
# physical_activity_light                          -0.300625
# physical_activity_moderate                       -0.876280
# physical_activity_vigorous                       -0.644484
# sleep_TST                                         0.999969
# sleep_WASO                                       -0.867140
# sleep_PTA                                         0.999969
# sleep_NWB                                        -0.647099
# sleep_SOL                                        -0.457945
# sleep_SRI                                         0.999566
# cosinorage                                        1.000000
# cosinorage_advance                                1.000000
# cosinor_age_prediction_error                      1.000000
#
# [22 rows x 22 columns]
